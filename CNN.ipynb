# %% [markdown]
# # MOAI 2025 Training
#
# 本題目是 MOAI 2025 的訓練題目
#
# 你將使用 PyTorch 來構建一個卷積神經網絡（CNN）模型，用於識別手寫數字，請按照以下步驟完成任務。
#
# 第一段代碼中的 TaskGrader 是一個評分器，請不要修改。可以點擊代碼塊中左側的深色部分將代碼摺疊。

# %%
# 此部分為評分器，請勿編輯此單元格

import torch
import pandas as pd


class TaskGrader:
    def __init__(self):
        self.q1_1_pass = False
        self.q1_2_pass = False
        self.q1_3_pass = False

        self.q2_1_pass = False
        self.q2_2_pass = False
        self.q2_3_pass = False
        self.q2_4_pass = False
        self.q2_5_pass = False

        self.q3_1_pass = False
        self.q3_2_pass = False

    def q1_1_check(self, images_raw, labels_raw):
        try:
            assert isinstance(images_raw, torch.Tensor), "圖片應該是 torch.Tensor 類型"
            assert images_raw.shape == (60000, 28, 28), f"圖片維度大小應該是 (60000, 28, 28)，現在是{images_raw.shape}"

            assert isinstance(labels_raw, pd.DataFrame), "標籤應該是 pandas DataFrame 類型"
            assert len(labels_raw) == 60000, f"標籤應該有 60000 行，現在是 {len(labels_raw)}"
        except AssertionError as e:
            print("Q1.1未通過:", str(e))
            return

        self.q1_1_pass = True
        print("Q1.1通過 (5分)")

    def q1_2_check(self, images, labels):
        try:
            assert isinstance(images, torch.Tensor), "歸一化後的圖像必須是 torch.Tensor 類型"
            assert isinstance(labels, torch.Tensor), "標籤必須是 torch.Tensor 類型"

            assert -0.1 < images.mean() < 0.1, f"歸一化圖像的均值應接近0，現在是{images.mean()}"
            assert 0.9 < images.std() < 1.1, f"歸一化圖像的標準差應接近1，現在是{images.std()}"
        except AssertionError as e:
            print("Q1.2未通過:", str(e))
            return

        self.q1_2_pass = True
        print("Q1.2通過 (5分)")

    def q1_3_check(self, train_dataset, val_dataset):
        try:
            total_size = len(train_dataset) + len(val_dataset)
            train_ratio = len(train_dataset) / total_size

            assert 0.79 <= train_ratio <= 0.81, f"訓練-驗證集分割應為8:2，現在是{train_ratio:.2f}:{1 - train_ratio:.2f}"
        except AssertionError as e:
            print("Q1.3未通過:", str(e))
            return

        self.q1_3_pass = True
        print("Q1.3通過 (5分)")

    def q2_check(self, model):
        try:
            for name, module in model.named_modules():
                if isinstance(module, torch.nn.Conv2d):
                    self.q2_1_pass = True
                elif isinstance(module, torch.nn.MaxPool2d):
                    self.q2_2_pass = True
                elif any(
                    isinstance(module, act)
                    for act in [
                        torch.nn.ReLU,
                        torch.nn.Sigmoid,
                        torch.nn.Tanh,
                        torch.nn.ELU,
                        torch.nn.LeakyReLU,
                        torch.nn.PReLU,
                    ]
                ):
                    self.q2_3_pass = True
                elif isinstance(module, torch.nn.Linear):
                    if module.out_features == 10:
                        self.q2_4_pass = True

            x = torch.randn(1, 28, 28).to(next(model.parameters()).device)
            output = model(x)
            if output.shape[1] == 10:
                self.q2_5_pass = True

        except Exception:
            pass

        checks = [
            (self.q2_1_pass, "Q2.1", "模型應包含卷積層", 2),
            (self.q2_2_pass, "Q2.2", "模型應包含池化層", 2),
            (self.q2_3_pass, "Q2.3", "模型應包含激活函數", 2),
            (self.q2_4_pass, "Q2.4", "模型應包含輸出層", 2),
            (self.q2_5_pass, "Q2.5", "未能成功定義前向傳播，輸出分類結果", 7),
        ]

        for check in checks:
            if not check[0]:
                print(f"{check[1]}未通過: {check[2]}")
            else:
                print(f"{check[1]}通過 ({check[3]}分)")

    def q3_1_check(self, criterion, optimizer):
        try:
            valid_loss_fns = [
                torch.nn.CrossEntropyLoss,
                torch.nn.NLLLoss,
                torch.nn.MSELoss,
                torch.nn.L1Loss,
                torch.nn.SmoothL1Loss,
                torch.nn.HuberLoss,
                torch.nn.SoftMarginLoss,
                torch.nn.MultiLabelMarginLoss,
                torch.nn.MultiLabelSoftMarginLoss,
            ]

            valid_optimizers = [
                torch.optim.SGD,
                torch.optim.Adam,
                torch.optim.RMSprop,
                torch.optim.Adagrad,
                torch.optim.Adadelta,
                torch.optim.Adamax,
                torch.optim.AdamW,
                torch.optim.SparseAdam,
                torch.optim.ASGD,
                torch.optim.Rprop,
                torch.optim.LBFGS,
                torch.optim.NAdam,
            ]

            is_valid_loss = any(isinstance(criterion, loss_fn) for loss_fn in valid_loss_fns)
            is_valid_optimizer = any(isinstance(optimizer, opt) for opt in valid_optimizers)

            assert is_valid_loss, "必須使用有效的損失函數 (CrossEntropyLoss, NLLLoss, MSELoss 等)"
            assert is_valid_optimizer, "必須使用有效的優化器 (SGD, Adam, RMSprop 等)"

        except Exception as e:
            print("Q3.1未通過:", str(e))
            return

        self.q3_1_pass = True
        print("Q3.1通過 (5分)")

    def q3_2_check(self, train_losses, val_losses, train_accs, val_accs):
        try:
            assert len(train_losses) >= 5, f"應至少訓練5個週期，目前{len(train_losses)}"
            assert len(val_losses) >= 5, f"應至少驗證5個週期，目前{len(val_losses)}"
            assert len(train_accs) >= 5, f"應至少記錄5個週期的訓練準確率，目前{len(train_accs)}"
            assert len(val_accs) >= 5, f"應至少記錄5個週期的驗證準確率，目前{len(val_accs)}"

            assert train_losses[0] > train_losses[-1], "訓練損失應隨着週期減少"

            assert train_accs[-1] > 0.5, f"最終訓練準確率應更高，目前{train_accs[-1]:.2f}"
            assert val_accs[-1] > 0.5, f"最終驗證準確率應更高，目前{val_accs[-1]:.2f}"

        except Exception as e:
            print("Q3.2未通過:", str(e))
            return

        self.q3_2_pass = True
        print("Q3.2通過 (15分)")


task_grader = TaskGrader()

# 此部分為評分器，請勿編輯此單元格

# %% [markdown]
# ### 小題 1：數據讀取與預處理 (15 分)
#
# 數據集包括以下內容
#
# - 訓練圖像數據：train_images.pt (shape: [60000, 28, 28])
# - 訓練標籤數據：train_labels.csv
# - 測試圖像數據：test_images.pt (shape: [10000, 28, 28])
#
# 其中，訓練數據集提供圖像和標籤，測試數據集只提供圖像，不提供標籤
#
# **本題目要求完成以下內容**
#
# 1. 讀取數據集圖片和標籤 (5分)
# 2. 將數據集按 **8:2** 的比例劃分為訓練集和驗證集。 (5分)
# 3. 將圖像數據歸一化並轉換為 Tensor。 (5分)

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, random_split
import pandas as pd

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


import torch
from torch import optim
from torch import nn
from torch.utils.data import DataLoader
from tqdm import tqdm

# !pip install torchvision
import torchvision

import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# TODO: 讀取數據集，'train-images.pt' 和 'train-labels.csv'
images_raw = torch.load('/kaggle/input/moai-2025-training/train_images.pt', weights_only=False)
labels_raw = pd.read_csv('/kaggle/input/moai-2025-training/train_labels.csv')

# TODO: 歸一化數據集並轉換為 torch.Tensor
images = images_raw/255.0
labels = torch.tensor(labels_raw['label'].values)


dataset = TensorDataset(images, labels)

# %%
# TODO: 創建數據集，並按照 8:2 劃分成訓練集和驗證集

train_dataset, val_dataset = random_split(dataset, [52000, 8000])

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=128)

# %%
# 以下代碼執行後可以判斷你的作答是否正確，請勿修改

task_grader.q1_1_check(images_raw, labels_raw)
task_grader.q1_2_check(images, labels)
task_grader.q1_3_check(train_dataset, val_dataset)

# %% [markdown]
# ### 可視化
#
# 以下是一段將數據集進行可視化的代碼，如果前面的代碼編寫正確，會顯示兩行的圖片，第一行是訓練集，第二行是驗證集

# %%
import matplotlib.pyplot as plt
import numpy as np

def visualize_samples(loader, title):
    images, labels = next(iter(loader))
    images = images[:5]
    labels = labels[:5]
    
    plt.figure(figsize=(15, 3))
    plt.suptitle(title, fontsize=16)
    
    for i in range(5):
        plt.subplot(1, 5, i+1)
        img = images[i].squeeze()
        plt.imshow(img.numpy(), cmap='gray' if img.dim() == 2 else None)
        plt.title(f"Label: {labels[i].item()}")
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# 可視化訓練集樣本
visualize_samples(train_loader, "Training set")

# 可視化驗證集樣本
visualize_samples(val_loader, "Validation set")

# %% [markdown]
# ### 小題 2：構建 CNN 模型 (15 分)
#
# 定義一個簡單的 CNN 模型，滿足以下條件：
#
# 1. 至少包含兩個卷積層 (`nn.Conv2d`) (2分)
# 2. 至少包含兩個池化層 (`nn.MaxPool2d`) (2分)
# 3. 使用激活函數 (`nn.ReLU`, `nn.Sigmoid`, `nn.Tanh`, `nn.ELU`, `nn.LeakyReLU`, `nn.PreLU` 等) (2分)
# 4. 定義輸出層，輸出一個 10 維向量 (對應 10 個類別) (2分)
# 5. 定義前向傳播，將以上所有網絡層連接（7分）

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        # 使用更多通道和更深的层次
        self.features = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.25),
            
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.25),
            
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Dropout(0.4),
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(128 * 7 * 7, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.4),
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(inplace=True),
            nn.Dropout(0.4),
            nn.Linear(128, 10)
        )
        
    def forward(self, x):
        x = x.view(-1, 1, 28, 28)
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x      
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNN().to(device)
print(model)
# Out:
# CNN(
#   (features): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU(inplace=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Dropout(p=0.25, inplace=False)
#     (16): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): ReLU(inplace=True)
#     (19): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (21): ReLU(inplace=True)
#     (22): Dropout(p=0.4, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=6272, out_features=256, bias=True)
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): Dropout(p=0.4, inplace=False)
#     (8): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %%
# 以下代碼執行後可以判斷你的作答是否正確，請勿修改

task_grader.q2_check(model)

# %% [markdown]
# ### 小題 3：訓練模型 (20 分)
#
# 1. 選擇損失函數 (`MSELoss`, `CrossEntropyLoss` 等) (2分)
# 2. 選擇優化器（`SGD`, `Adam` 等），並設置學習率。 (3分)
# 3. 模型訓練**至少** 5 個 epoch，並在每個 epoch 結束時分別打印訓練集和驗證集的損失函數和準確率。 (15分)

# %%
from sklearn.metrics import accuracy_score

# 選擇損失函數
criterion = nn.CrossEntropyLoss()

# 選擇優化器
optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-4)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=3, verbose=True
)
train_losses = []
train_accs = []
val_losses = []
val_accs = []

# 訓練循環
for epoch in range(100):
    model.train()
    for batch_idx, (images, labels) in enumerate(train_loader):
        optimizer.zero_grad()
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        preds = outputs.argmax(dim=1)
        train_loss = loss.item()
        train_acc = accuracy_score(labels.cpu().numpy(), preds.cpu().numpy())

        # 以下是記錄損失函數和準確率的代碼，不用修改
        if batch_idx % 100 == 0:
            train_losses.append(train_loss)
            train_accs.append(train_acc)
            print(f"Epoch {epoch+1}, Batch {batch_idx}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc * 100:.2f}%")

    model.eval()

    val_preds, val_true = [], []
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            outputs = model(images)

            val_preds.extend(outputs.argmax(dim=1).cpu().numpy())
            val_true.extend(labels.numpy())

    val_loss = criterion(outputs.cpu(), labels).item()
    val_acc = accuracy_score(val_true, val_preds)

    # 以下是記錄損失函數和準確率的代碼，不用修改
    val_accs.append(val_acc)
    val_losses.append(val_loss)
    print(f"Epoch {epoch+1}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc * 100:.2f}%")
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1, Batch 0, Train Loss: 0.4547, Train Accuracy: 95.31%
# Epoch 1, Batch 100, Train Loss: 0.2840, Train Accuracy: 96.09%
# Epoch 1, Batch 200, Train Loss: 0.1625, Train Accuracy: 98.44%
# Epoch 1, Batch 300, Train Loss: 0.1564, Train Accuracy: 96.88%
# Epoch 1, Batch 400, Train Loss: 0.0877, Train Accuracy: 100.00%
# Epoch 1, Val Loss: 0.0280, Val Accuracy: 98.56%
# Epoch 2, Batch 0, Train Loss: 0.0901, Train Accuracy: 99.22%
# Epoch 2, Batch 100, Train Loss: 0.1498, Train Accuracy: 97.66%
# Epoch 2, Batch 200, Train Loss: 0.1267, Train Accuracy: 97.66%
# Epoch 2, Batch 300, Train Loss: 0.1267, Train Accuracy: 96.88%
# Epoch 2, Batch 400, Train Loss: 0.0506, Train Accuracy: 100.00%
# Epoch 2, Val Loss: 0.0103, Val Accuracy: 99.01%
# Epoch 3, Batch 0, Train Loss: 0.0633, Train Accuracy: 99.22%
# Epoch 3, Batch 100, Train Loss: 0.1578, Train Accuracy: 96.09%
# Epoch 3, Batch 200, Train Loss: 0.0445, Train Accuracy: 99.22%
# Epoch 3, Batch 300, Train Loss: 0.0437, Train Accuracy: 100.00%
# Epoch 3, Batch 400, Train Loss: 0.0821, Train Accuracy: 97.66%
# Epoch 3, Val Loss: 0.0031, Val Accuracy: 99.09%
# Epoch 4, Batch 0, Train Loss: 0.0861, Train Accuracy: 97.66%
# Epoch 4, Batch 100, Train Loss: 0.0232, Train Accuracy: 100.00%
# Epoch 4, Batch 200, Train Loss: 0.0278, Train Accuracy: 100.00%
# Epoch 4, Batch 300, Train Loss: 0.0250, Train Accuracy: 99.22%
# Epoch 4, Batch 400, Train Loss: 0.0497, Train Accuracy: 98.44%
# Epoch 4, Val Loss: 0.0033, Val Accuracy: 99.30%
# Epoch 5, Batch 0, Train Loss: 0.0248, Train Accuracy: 99.22%
# Epoch 5, Batch 100, Train Loss: 0.0425, Train Accuracy: 99.22%
# Epoch 5, Batch 200, Train Loss: 0.0124, Train Accuracy: 100.00%
# Epoch 5, Batch 300, Train Loss: 0.0243, Train Accuracy: 100.00%
# Epoch 5, Batch 400, Train Loss: 0.0301, Train Accuracy: 99.22%
# Epoch 5, Val Loss: 0.0024, Val Accuracy: 99.25%
# Epoch 6, Batch 0, Train Loss: 0.0182, Train Accuracy: 100.00%
# Epoch 6, Batch 100, Train Loss: 0.0205, Train Accuracy: 100.00%
# Epoch 6, Batch 200, Train Loss: 0.0421, Train Accuracy: 99.22%
# Epoch 6, Batch 300, Train Loss: 0.0307, Train Accuracy: 98.44%
# Epoch 6, Batch 400, Train Loss: 0.0296, Train Accuracy: 98.44%
# Epoch 6, Val Loss: 0.0009, Val Accuracy: 99.33%
# Epoch 7, Batch 0, Train Loss: 0.0447, Train Accuracy: 98.44%
# Epoch 7, Batch 100, Train Loss: 0.0149, Train Accuracy: 100.00%
# Epoch 7, Batch 200, Train Loss: 0.0226, Train Accuracy: 100.00%
# Epoch 7, Batch 300, Train Loss: 0.0938, Train Accuracy: 98.44%
# Epoch 7, Batch 400, Train Loss: 0.0358, Train Accuracy: 98.44%
# Epoch 7, Val Loss: 0.0007, Val Accuracy: 99.36%
# Epoch 8, Batch 0, Train Loss: 0.0952, Train Accuracy: 97.66%
# Epoch 8, Batch 100, Train Loss: 0.0109, Train Accuracy: 100.00%
# Epoch 8, Batch 200, Train Loss: 0.0404, Train Accuracy: 98.44%
# Epoch 8, Batch 300, Train Loss: 0.0567, Train Accuracy: 99.22%
# Epoch 8, Batch 400, Train Loss: 0.0764, Train Accuracy: 96.88%
# Epoch 8, Val Loss: 0.0005, Val Accuracy: 99.31%
# Epoch 9, Batch 0, Train Loss: 0.0232, Train Accuracy: 99.22%
# Epoch 9, Batch 100, Train Loss: 0.0445, Train Accuracy: 99.22%
# Epoch 9, Batch 200, Train Loss: 0.0364, Train Accuracy: 98.44%
# Epoch 9, Batch 300, Train Loss: 0.0097, Train Accuracy: 100.00%
# Epoch 9, Batch 400, Train Loss: 0.0370, Train Accuracy: 99.22%
# Epoch 9, Val Loss: 0.0005, Val Accuracy: 99.38%
# Epoch 10, Batch 0, Train Loss: 0.0459, Train Accuracy: 98.44%
# Epoch 10, Batch 100, Train Loss: 0.0286, Train Accuracy: 99.22%
# Epoch 10, Batch 200, Train Loss: 0.0088, Train Accuracy: 100.00%
# Epoch 10, Batch 300, Train Loss: 0.0259, Train Accuracy: 99.22%
# Epoch 10, Batch 400, Train Loss: 0.0213, Train Accuracy: 100.00%
# Epoch 10, Val Loss: 0.0004, Val Accuracy: 99.35%
# Epoch 11, Batch 0, Train Loss: 0.0444, Train Accuracy: 99.22%
# Epoch 11, Batch 100, Train Loss: 0.0415, Train Accuracy: 99.22%
# Epoch 11, Batch 200, Train Loss: 0.0073, Train Accuracy: 100.00%
# Epoch 11, Batch 300, Train Loss: 0.0096, Train Accuracy: 100.00%
# Epoch 11, Batch 400, Train Loss: 0.0469, Train Accuracy: 98.44%
# Epoch 11, Val Loss: 0.0004, Val Accuracy: 99.35%
# Epoch 12, Batch 0, Train Loss: 0.0046, Train Accuracy: 100.00%
# Epoch 12, Batch 100, Train Loss: 0.0119, Train Accuracy: 99.22%
# Epoch 12, Batch 200, Train Loss: 0.0503, Train Accuracy: 99.22%
# Epoch 12, Batch 300, Train Loss: 0.0932, Train Accuracy: 98.44%
# Epoch 12, Batch 400, Train Loss: 0.0087, Train Accuracy: 100.00%
# Epoch 12, Val Loss: 0.0004, Val Accuracy: 99.48%
# Epoch 13, Batch 0, Train Loss: 0.0255, Train Accuracy: 99.22%
# Epoch 13, Batch 100, Train Loss: 0.0335, Train Accuracy: 99.22%
# Epoch 13, Batch 200, Train Loss: 0.0075, Train Accuracy: 100.00%
# Epoch 13, Batch 300, Train Loss: 0.0212, Train Accuracy: 99.22%
# Epoch 13, Batch 400, Train Loss: 0.0051, Train Accuracy: 100.00%
# Epoch 13, Val Loss: 0.0003, Val Accuracy: 99.36%
# Epoch 14, Batch 0, Train Loss: 0.0162, Train Accuracy: 99.22%
# Epoch 14, Batch 100, Train Loss: 0.0221, Train Accuracy: 99.22%
# Epoch 14, Batch 200, Train Loss: 0.0455, Train Accuracy: 99.22%
# Epoch 14, Batch 300, Train Loss: 0.0112, Train Accuracy: 100.00%
# Epoch 14, Batch 400, Train Loss: 0.0093, Train Accuracy: 100.00%
# Epoch 14, Val Loss: 0.0003, Val Accuracy: 99.44%
# Epoch 15, Batch 0, Train Loss: 0.0061, Train Accuracy: 100.00%
# Epoch 15, Batch 100, Train Loss: 0.0101, Train Accuracy: 100.00%
# Epoch 15, Batch 200, Train Loss: 0.0306, Train Accuracy: 99.22%
# Epoch 15, Batch 300, Train Loss: 0.0185, Train Accuracy: 99.22%
# Epoch 15, Batch 400, Train Loss: 0.0063, Train Accuracy: 100.00%
# Epoch 15, Val Loss: 0.0002, Val Accuracy: 99.40%
# Epoch 16, Batch 0, Train Loss: 0.0134, Train Accuracy: 100.00%
# Epoch 16, Batch 100, Train Loss: 0.0118, Train Accuracy: 100.00%
# Epoch 16, Batch 200, Train Loss: 0.0305, Train Accuracy: 99.22%
# Epoch 16, Batch 300, Train Loss: 0.0121, Train Accuracy: 99.22%
# Epoch 16, Batch 400, Train Loss: 0.0130, Train Accuracy: 100.00%
# Epoch 16, Val Loss: 0.0002, Val Accuracy: 99.38%
# Epoch 17, Batch 0, Train Loss: 0.0251, Train Accuracy: 98.44%
# Epoch 17, Batch 100, Train Loss: 0.0326, Train Accuracy: 99.22%
# Epoch 17, Batch 200, Train Loss: 0.0277, Train Accuracy: 99.22%
# Epoch 17, Batch 300, Train Loss: 0.0183, Train Accuracy: 99.22%
# Epoch 17, Batch 400, Train Loss: 0.0373, Train Accuracy: 98.44%
# Epoch 17, Val Loss: 0.0002, Val Accuracy: 99.48%
# Epoch 18, Batch 0, Train Loss: 0.0552, Train Accuracy: 98.44%
# Epoch 18, Batch 100, Train Loss: 0.0034, Train Accuracy: 100.00%
# Epoch 18, Batch 200, Train Loss: 0.0056, Train Accuracy: 100.00%
# Epoch 18, Batch 300, Train Loss: 0.0148, Train Accuracy: 99.22%
# Epoch 18, Batch 400, Train Loss: 0.0114, Train Accuracy: 99.22%
# Epoch 18, Val Loss: 0.0002, Val Accuracy: 99.39%
# Epoch 19, Batch 0, Train Loss: 0.0038, Train Accuracy: 100.00%
# Epoch 19, Batch 100, Train Loss: 0.0048, Train Accuracy: 100.00%
# Epoch 19, Batch 200, Train Loss: 0.0023, Train Accuracy: 100.00%
# Epoch 19, Batch 300, Train Loss: 0.0233, Train Accuracy: 98.44%
# Epoch 19, Batch 400, Train Loss: 0.0088, Train Accuracy: 100.00%
# Epoch 19, Val Loss: 0.0002, Val Accuracy: 99.38%
# Epoch 20, Batch 0, Train Loss: 0.0037, Train Accuracy: 100.00%
# Epoch 20, Batch 100, Train Loss: 0.0025, Train Accuracy: 100.00%
# Epoch 20, Batch 200, Train Loss: 0.0073, Train Accuracy: 100.00%
# Epoch 20, Batch 300, Train Loss: 0.0149, Train Accuracy: 99.22%
# Epoch 20, Batch 400, Train Loss: 0.0185, Train Accuracy: 99.22%
# Epoch 20, Val Loss: 0.0001, Val Accuracy: 99.46%
# Epoch 21, Batch 0, Train Loss: 0.0768, Train Accuracy: 98.44%
# Epoch 21, Batch 100, Train Loss: 0.0154, Train Accuracy: 99.22%
# Epoch 21, Batch 200, Train Loss: 0.0547, Train Accuracy: 99.22%
# Epoch 21, Batch 300, Train Loss: 0.0059, Train Accuracy: 100.00%
# Epoch 21, Batch 400, Train Loss: 0.0047, Train Accuracy: 100.00%
# Epoch 21, Val Loss: 0.0001, Val Accuracy: 99.40%
# Epoch 22, Batch 0, Train Loss: 0.0037, Train Accuracy: 100.00%
# Epoch 22, Batch 100, Train Loss: 0.0024, Train Accuracy: 100.00%
# Epoch 22, Batch 200, Train Loss: 0.0112, Train Accuracy: 100.00%
# Epoch 22, Batch 300, Train Loss: 0.0047, Train Accuracy: 100.00%
# Epoch 22, Batch 400, Train Loss: 0.0038, Train Accuracy: 100.00%
# Epoch 22, Val Loss: 0.0001, Val Accuracy: 99.49%
# Epoch 23, Batch 0, Train Loss: 0.0178, Train Accuracy: 99.22%
# Epoch 23, Batch 100, Train Loss: 0.0216, Train Accuracy: 99.22%
# Epoch 23, Batch 200, Train Loss: 0.0198, Train Accuracy: 99.22%
# Epoch 23, Batch 300, Train Loss: 0.0590, Train Accuracy: 98.44%
# Epoch 23, Batch 400, Train Loss: 0.0043, Train Accuracy: 100.00%
# Epoch 23, Val Loss: 0.0001, Val Accuracy: 99.46%
# Epoch 24, Batch 0, Train Loss: 0.0635, Train Accuracy: 97.66%
# Epoch 24, Batch 100, Train Loss: 0.0150, Train Accuracy: 100.00%
# Epoch 24, Batch 200, Train Loss: 0.0140, Train Accuracy: 99.22%
# Epoch 24, Batch 300, Train Loss: 0.0218, Train Accuracy: 99.22%
# Epoch 24, Batch 400, Train Loss: 0.0032, Train Accuracy: 100.00%
# Epoch 24, Val Loss: 0.0002, Val Accuracy: 99.45%
# Epoch 25, Batch 0, Train Loss: 0.0229, Train Accuracy: 99.22%
# Epoch 25, Batch 100, Train Loss: 0.0298, Train Accuracy: 98.44%
# Epoch 25, Batch 200, Train Loss: 0.0170, Train Accuracy: 99.22%
# Epoch 25, Batch 300, Train Loss: 0.0096, Train Accuracy: 100.00%
# Epoch 25, Batch 400, Train Loss: 0.0349, Train Accuracy: 99.22%
# Epoch 25, Val Loss: 0.0001, Val Accuracy: 99.36%
# Epoch 26, Batch 0, Train Loss: 0.0088, Train Accuracy: 100.00%
# Epoch 26, Batch 100, Train Loss: 0.0315, Train Accuracy: 99.22%
# Epoch 26, Batch 200, Train Loss: 0.0065, Train Accuracy: 100.00%
# Epoch 26, Batch 300, Train Loss: 0.0188, Train Accuracy: 99.22%
# Epoch 26, Batch 400, Train Loss: 0.0118, Train Accuracy: 100.00%
# Epoch 26, Val Loss: 0.0001, Val Accuracy: 99.48%
# Epoch 27, Batch 0, Train Loss: 0.0043, Train Accuracy: 100.00%
# Epoch 27, Batch 100, Train Loss: 0.0227, Train Accuracy: 99.22%
# Epoch 27, Batch 200, Train Loss: 0.0057, Train Accuracy: 100.00%
# Epoch 27, Batch 300, Train Loss: 0.0030, Train Accuracy: 100.00%
# Epoch 27, Batch 400, Train Loss: 0.0080, Train Accuracy: 100.00%
# Epoch 27, Val Loss: 0.0002, Val Accuracy: 99.45%
# Epoch 28, Batch 0, Train Loss: 0.0172, Train Accuracy: 99.22%
# Epoch 28, Batch 100, Train Loss: 0.0098, Train Accuracy: 100.00%
# Epoch 28, Batch 200, Train Loss: 0.0388, Train Accuracy: 97.66%
# Epoch 28, Batch 300, Train Loss: 0.0197, Train Accuracy: 99.22%
# Epoch 28, Batch 400, Train Loss: 0.0297, Train Accuracy: 99.22%
# Epoch 28, Val Loss: 0.0001, Val Accuracy: 99.45%
# Epoch 29, Batch 0, Train Loss: 0.0069, Train Accuracy: 100.00%
# Epoch 29, Batch 100, Train Loss: 0.0302, Train Accuracy: 99.22%
# Epoch 29, Batch 200, Train Loss: 0.0895, Train Accuracy: 97.66%
# Epoch 29, Batch 300, Train Loss: 0.0025, Train Accuracy: 100.00%
# Epoch 29, Batch 400, Train Loss: 0.0281, Train Accuracy: 99.22%
# Epoch 29, Val Loss: 0.0001, Val Accuracy: 99.56%
# Epoch 30, Batch 0, Train Loss: 0.0159, Train Accuracy: 100.00%
# Epoch 30, Batch 100, Train Loss: 0.0111, Train Accuracy: 99.22%
# Epoch 30, Batch 200, Train Loss: 0.0018, Train Accuracy: 100.00%
# Epoch 30, Batch 300, Train Loss: 0.0305, Train Accuracy: 98.44%
# Epoch 30, Batch 400, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 30, Val Loss: 0.0001, Val Accuracy: 99.52%
# Epoch 31, Batch 0, Train Loss: 0.0012, Train Accuracy: 100.00%
# Epoch 31, Batch 100, Train Loss: 0.0026, Train Accuracy: 100.00%
# Epoch 31, Batch 200, Train Loss: 0.0112, Train Accuracy: 99.22%
# Epoch 31, Batch 300, Train Loss: 0.0067, Train Accuracy: 100.00%
# Epoch 31, Batch 400, Train Loss: 0.0057, Train Accuracy: 100.00%
# Epoch 31, Val Loss: 0.0009, Val Accuracy: 99.45%
# Epoch 32, Batch 0, Train Loss: 0.0025, Train Accuracy: 100.00%
# Epoch 32, Batch 100, Train Loss: 0.0191, Train Accuracy: 99.22%
# Epoch 32, Batch 200, Train Loss: 0.0012, Train Accuracy: 100.00%
# Epoch 32, Batch 300, Train Loss: 0.0698, Train Accuracy: 98.44%
# Epoch 32, Batch 400, Train Loss: 0.0022, Train Accuracy: 100.00%
# Epoch 32, Val Loss: 0.0002, Val Accuracy: 99.42%
# Epoch 33, Batch 0, Train Loss: 0.0055, Train Accuracy: 100.00%
# Epoch 33, Batch 100, Train Loss: 0.0019, Train Accuracy: 100.00%
# Epoch 33, Batch 200, Train Loss: 0.0021, Train Accuracy: 100.00%
# Epoch 33, Batch 300, Train Loss: 0.0025, Train Accuracy: 100.00%
# Epoch 33, Batch 400, Train Loss: 0.0017, Train Accuracy: 100.00%
# Epoch 33, Val Loss: 0.0000, Val Accuracy: 99.51%
# Epoch 34, Batch 0, Train Loss: 0.0215, Train Accuracy: 99.22%
# Epoch 34, Batch 100, Train Loss: 0.0133, Train Accuracy: 100.00%
# Epoch 34, Batch 200, Train Loss: 0.0071, Train Accuracy: 100.00%
# Epoch 34, Batch 300, Train Loss: 0.0064, Train Accuracy: 100.00%
# Epoch 34, Batch 400, Train Loss: 0.0144, Train Accuracy: 100.00%
# Epoch 34, Val Loss: 0.0001, Val Accuracy: 99.56%
# Epoch 35, Batch 0, Train Loss: 0.0153, Train Accuracy: 99.22%
# Epoch 35, Batch 100, Train Loss: 0.0050, Train Accuracy: 100.00%
# Epoch 35, Batch 200, Train Loss: 0.0012, Train Accuracy: 100.00%
# Epoch 35, Batch 300, Train Loss: 0.0013, Train Accuracy: 100.00%
# Epoch 35, Batch 400, Train Loss: 0.0054, Train Accuracy: 100.00%
# Epoch 35, Val Loss: 0.0001, Val Accuracy: 99.46%
# Epoch 36, Batch 0, Train Loss: 0.0296, Train Accuracy: 99.22%
# Epoch 36, Batch 100, Train Loss: 0.0049, Train Accuracy: 100.00%
# Epoch 36, Batch 200, Train Loss: 0.0034, Train Accuracy: 100.00%
# Epoch 36, Batch 300, Train Loss: 0.0463, Train Accuracy: 98.44%
# Epoch 36, Batch 400, Train Loss: 0.0085, Train Accuracy: 100.00%
# Epoch 36, Val Loss: 0.0001, Val Accuracy: 99.50%
# Epoch 37, Batch 0, Train Loss: 0.0013, Train Accuracy: 100.00%
# Epoch 37, Batch 100, Train Loss: 0.0031, Train Accuracy: 100.00%
# Epoch 37, Batch 200, Train Loss: 0.0057, Train Accuracy: 100.00%
# Epoch 37, Batch 300, Train Loss: 0.0099, Train Accuracy: 99.22%
# Epoch 37, Batch 400, Train Loss: 0.0104, Train Accuracy: 100.00%
# Epoch 37, Val Loss: 0.0001, Val Accuracy: 99.55%
# Epoch 38, Batch 0, Train Loss: 0.0072, Train Accuracy: 100.00%
# Epoch 38, Batch 100, Train Loss: 0.0018, Train Accuracy: 100.00%
# Epoch 38, Batch 200, Train Loss: 0.0229, Train Accuracy: 98.44%
# Epoch 38, Batch 300, Train Loss: 0.0054, Train Accuracy: 100.00%
# Epoch 38, Batch 400, Train Loss: 0.0115, Train Accuracy: 99.22%
# Epoch 38, Val Loss: 0.0000, Val Accuracy: 99.54%
# Epoch 39, Batch 0, Train Loss: 0.0124, Train Accuracy: 99.22%
# Epoch 39, Batch 100, Train Loss: 0.0081, Train Accuracy: 99.22%
# Epoch 39, Batch 200, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 39, Batch 300, Train Loss: 0.0059, Train Accuracy: 100.00%
# Epoch 39, Batch 400, Train Loss: 0.0410, Train Accuracy: 98.44%
# Epoch 39, Val Loss: 0.0001, Val Accuracy: 99.54%
# Epoch 40, Batch 0, Train Loss: 0.0186, Train Accuracy: 99.22%
# Epoch 40, Batch 100, Train Loss: 0.0012, Train Accuracy: 100.00%
# Epoch 40, Batch 200, Train Loss: 0.0017, Train Accuracy: 100.00%
# Epoch 40, Batch 300, Train Loss: 0.0079, Train Accuracy: 100.00%
# Epoch 40, Batch 400, Train Loss: 0.0007, Train Accuracy: 100.00%
# Epoch 40, Val Loss: 0.0001, Val Accuracy: 99.52%
# Epoch 41, Batch 0, Train Loss: 0.0727, Train Accuracy: 97.66%
# Epoch 41, Batch 100, Train Loss: 0.0141, Train Accuracy: 99.22%
# Epoch 41, Batch 200, Train Loss: 0.0099, Train Accuracy: 99.22%
# Epoch 41, Batch 300, Train Loss: 0.0284, Train Accuracy: 99.22%
# Epoch 41, Batch 400, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 41, Val Loss: 0.0000, Val Accuracy: 99.61%
# Epoch 42, Batch 0, Train Loss: 0.0076, Train Accuracy: 99.22%
# Epoch 42, Batch 100, Train Loss: 0.0014, Train Accuracy: 100.00%
# Epoch 42, Batch 200, Train Loss: 0.0042, Train Accuracy: 100.00%
# Epoch 42, Batch 300, Train Loss: 0.0247, Train Accuracy: 98.44%
# Epoch 42, Batch 400, Train Loss: 0.0010, Train Accuracy: 100.00%
# Epoch 42, Val Loss: 0.0002, Val Accuracy: 99.40%
# Epoch 43, Batch 0, Train Loss: 0.0028, Train Accuracy: 100.00%
# Epoch 43, Batch 100, Train Loss: 0.0034, Train Accuracy: 100.00%
# Epoch 43, Batch 200, Train Loss: 0.0036, Train Accuracy: 100.00%
# Epoch 43, Batch 300, Train Loss: 0.0080, Train Accuracy: 100.00%
# Epoch 43, Batch 400, Train Loss: 0.0012, Train Accuracy: 100.00%
# Epoch 43, Val Loss: 0.0000, Val Accuracy: 99.49%
# Epoch 44, Batch 0, Train Loss: 0.0248, Train Accuracy: 99.22%
# Epoch 44, Batch 100, Train Loss: 0.0082, Train Accuracy: 100.00%
# Epoch 44, Batch 200, Train Loss: 0.0037, Train Accuracy: 100.00%
# Epoch 44, Batch 300, Train Loss: 0.0506, Train Accuracy: 99.22%
# Epoch 44, Batch 400, Train Loss: 0.0326, Train Accuracy: 99.22%
# Epoch 44, Val Loss: 0.0000, Val Accuracy: 99.50%
# Epoch 45, Batch 0, Train Loss: 0.0090, Train Accuracy: 99.22%
# Epoch 45, Batch 100, Train Loss: 0.0041, Train Accuracy: 100.00%
# Epoch 45, Batch 200, Train Loss: 0.0099, Train Accuracy: 99.22%
# Epoch 45, Batch 300, Train Loss: 0.0031, Train Accuracy: 100.00%
# Epoch 45, Batch 400, Train Loss: 0.0202, Train Accuracy: 99.22%
# Epoch 45, Val Loss: 0.0001, Val Accuracy: 99.50%
# Epoch 46, Batch 0, Train Loss: 0.0056, Train Accuracy: 100.00%
# Epoch 46, Batch 100, Train Loss: 0.0027, Train Accuracy: 100.00%
# Epoch 46, Batch 200, Train Loss: 0.0138, Train Accuracy: 99.22%
# Epoch 46, Batch 300, Train Loss: 0.0021, Train Accuracy: 100.00%
# Epoch 46, Batch 400, Train Loss: 0.0140, Train Accuracy: 99.22%
# Epoch 46, Val Loss: 0.0000, Val Accuracy: 99.51%
# Epoch 47, Batch 0, Train Loss: 0.0029, Train Accuracy: 100.00%
# Epoch 47, Batch 100, Train Loss: 0.0020, Train Accuracy: 100.00%
# Epoch 47, Batch 200, Train Loss: 0.0029, Train Accuracy: 100.00%
# Epoch 47, Batch 300, Train Loss: 0.0015, Train Accuracy: 100.00%
# Epoch 47, Batch 400, Train Loss: 0.0159, Train Accuracy: 99.22%
# Epoch 47, Val Loss: 0.0001, Val Accuracy: 99.51%
# Epoch 48, Batch 0, Train Loss: 0.0183, Train Accuracy: 99.22%
# Epoch 48, Batch 100, Train Loss: 0.0032, Train Accuracy: 100.00%
# Epoch 48, Batch 200, Train Loss: 0.0035, Train Accuracy: 100.00%
# Epoch 48, Batch 300, Train Loss: 0.0677, Train Accuracy: 98.44%
# Epoch 48, Batch 400, Train Loss: 0.0126, Train Accuracy: 99.22%
# Epoch 48, Val Loss: 0.0000, Val Accuracy: 99.58%
# Epoch 49, Batch 0, Train Loss: 0.0024, Train Accuracy: 100.00%
# Epoch 49, Batch 100, Train Loss: 0.0029, Train Accuracy: 100.00%
# Epoch 49, Batch 200, Train Loss: 0.0029, Train Accuracy: 100.00%
# Epoch 49, Batch 300, Train Loss: 0.0068, Train Accuracy: 99.22%
# Epoch 49, Batch 400, Train Loss: 0.0064, Train Accuracy: 100.00%
# Epoch 49, Val Loss: 0.0000, Val Accuracy: 99.58%
# Epoch 50, Batch 0, Train Loss: 0.0096, Train Accuracy: 100.00%
# Epoch 50, Batch 100, Train Loss: 0.0094, Train Accuracy: 99.22%
# Epoch 50, Batch 200, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 50, Batch 300, Train Loss: 0.0126, Train Accuracy: 99.22%
# Epoch 50, Batch 400, Train Loss: 0.0042, Train Accuracy: 100.00%
# Epoch 50, Val Loss: 0.0000, Val Accuracy: 99.58%
# Epoch 51, Batch 0, Train Loss: 0.0105, Train Accuracy: 99.22%
# Epoch 51, Batch 100, Train Loss: 0.0037, Train Accuracy: 100.00%
# Epoch 51, Batch 200, Train Loss: 0.0010, Train Accuracy: 100.00%
# Epoch 51, Batch 300, Train Loss: 0.0056, Train Accuracy: 100.00%
# Epoch 51, Batch 400, Train Loss: 0.0031, Train Accuracy: 100.00%
# Epoch 51, Val Loss: 0.0001, Val Accuracy: 99.56%
# Epoch 52, Batch 0, Train Loss: 0.0245, Train Accuracy: 97.66%
# Epoch 52, Batch 100, Train Loss: 0.0012, Train Accuracy: 100.00%
# Epoch 52, Batch 200, Train Loss: 0.0013, Train Accuracy: 100.00%
# Epoch 52, Batch 300, Train Loss: 0.0022, Train Accuracy: 100.00%
# Epoch 52, Batch 400, Train Loss: 0.0034, Train Accuracy: 100.00%
# Epoch 52, Val Loss: 0.0001, Val Accuracy: 99.58%
# Epoch 53, Batch 0, Train Loss: 0.0175, Train Accuracy: 99.22%
# Epoch 53, Batch 100, Train Loss: 0.0271, Train Accuracy: 97.66%
# Epoch 53, Batch 200, Train Loss: 0.0013, Train Accuracy: 100.00%
# Epoch 53, Batch 300, Train Loss: 0.0021, Train Accuracy: 100.00%
# Epoch 53, Batch 400, Train Loss: 0.0013, Train Accuracy: 100.00%
# Epoch 53, Val Loss: 0.0001, Val Accuracy: 99.50%
# Epoch 54, Batch 0, Train Loss: 0.0026, Train Accuracy: 100.00%
# Epoch 54, Batch 100, Train Loss: 0.0058, Train Accuracy: 100.00%
# Epoch 54, Batch 200, Train Loss: 0.0286, Train Accuracy: 99.22%
# Epoch 54, Batch 300, Train Loss: 0.0025, Train Accuracy: 100.00%
# Epoch 54, Batch 400, Train Loss: 0.0317, Train Accuracy: 99.22%
# Epoch 54, Val Loss: 0.0000, Val Accuracy: 99.52%
# Epoch 55, Batch 0, Train Loss: 0.0064, Train Accuracy: 100.00%
# Epoch 55, Batch 100, Train Loss: 0.0014, Train Accuracy: 100.00%
# Epoch 55, Batch 200, Train Loss: 0.0046, Train Accuracy: 100.00%
# Epoch 55, Batch 300, Train Loss: 0.0044, Train Accuracy: 100.00%
# Epoch 55, Batch 400, Train Loss: 0.0047, Train Accuracy: 100.00%
# Epoch 55, Val Loss: 0.0001, Val Accuracy: 99.54%
# Epoch 56, Batch 0, Train Loss: 0.0034, Train Accuracy: 100.00%
# Epoch 56, Batch 100, Train Loss: 0.0023, Train Accuracy: 100.00%
# Epoch 56, Batch 200, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 56, Batch 300, Train Loss: 0.0015, Train Accuracy: 100.00%
# Epoch 56, Batch 400, Train Loss: 0.0079, Train Accuracy: 100.00%
# Epoch 56, Val Loss: 0.0000, Val Accuracy: 99.49%
# Epoch 57, Batch 0, Train Loss: 0.0019, Train Accuracy: 100.00%
# Epoch 57, Batch 100, Train Loss: 0.0033, Train Accuracy: 100.00%
# Epoch 57, Batch 200, Train Loss: 0.0013, Train Accuracy: 100.00%
# Epoch 57, Batch 300, Train Loss: 0.0229, Train Accuracy: 98.44%
# Epoch 57, Batch 400, Train Loss: 0.0137, Train Accuracy: 99.22%
# Epoch 57, Val Loss: 0.0000, Val Accuracy: 99.50%
# Epoch 58, Batch 0, Train Loss: 0.0064, Train Accuracy: 100.00%
# Epoch 58, Batch 100, Train Loss: 0.0021, Train Accuracy: 100.00%
# Epoch 58, Batch 200, Train Loss: 0.0022, Train Accuracy: 100.00%
# Epoch 58, Batch 300, Train Loss: 0.0015, Train Accuracy: 100.00%
# Epoch 58, Batch 400, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 58, Val Loss: 0.0000, Val Accuracy: 99.54%
# Epoch 59, Batch 0, Train Loss: 0.0175, Train Accuracy: 99.22%
# Epoch 59, Batch 100, Train Loss: 0.0100, Train Accuracy: 100.00%
# Epoch 59, Batch 200, Train Loss: 0.0020, Train Accuracy: 100.00%
# Epoch 59, Batch 300, Train Loss: 0.0052, Train Accuracy: 100.00%
# Epoch 59, Batch 400, Train Loss: 0.0017, Train Accuracy: 100.00%
# Epoch 59, Val Loss: 0.0000, Val Accuracy: 99.46%
# Epoch 60, Batch 0, Train Loss: 0.0088, Train Accuracy: 99.22%
# Epoch 60, Batch 100, Train Loss: 0.0051, Train Accuracy: 100.00%
# Epoch 60, Batch 200, Train Loss: 0.0083, Train Accuracy: 99.22%
# Epoch 60, Batch 300, Train Loss: 0.0187, Train Accuracy: 99.22%
# Epoch 60, Batch 400, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 60, Val Loss: 0.0000, Val Accuracy: 99.54%
# Epoch 61, Batch 0, Train Loss: 0.0037, Train Accuracy: 100.00%
# Epoch 61, Batch 100, Train Loss: 0.0025, Train Accuracy: 100.00%
# Epoch 61, Batch 200, Train Loss: 0.0090, Train Accuracy: 99.22%
# Epoch 61, Batch 300, Train Loss: 0.0037, Train Accuracy: 100.00%
# Epoch 61, Batch 400, Train Loss: 0.0033, Train Accuracy: 100.00%
# Epoch 61, Val Loss: 0.0000, Val Accuracy: 99.49%
# Epoch 62, Batch 0, Train Loss: 0.0005, Train Accuracy: 100.00%
# Epoch 62, Batch 100, Train Loss: 0.0015, Train Accuracy: 100.00%
# Epoch 62, Batch 200, Train Loss: 0.0145, Train Accuracy: 99.22%
# Epoch 62, Batch 300, Train Loss: 0.0022, Train Accuracy: 100.00%
# Epoch 62, Batch 400, Train Loss: 0.0031, Train Accuracy: 100.00%
# Epoch 62, Val Loss: 0.0001, Val Accuracy: 99.51%
# Epoch 63, Batch 0, Train Loss: 0.0018, Train Accuracy: 100.00%
# Epoch 63, Batch 100, Train Loss: 0.0128, Train Accuracy: 99.22%
# Epoch 63, Batch 200, Train Loss: 0.0017, Train Accuracy: 100.00%
# Epoch 63, Batch 300, Train Loss: 0.0061, Train Accuracy: 100.00%
# Epoch 63, Batch 400, Train Loss: 0.0029, Train Accuracy: 100.00%
# Epoch 63, Val Loss: 0.0000, Val Accuracy: 99.51%
# Epoch 64, Batch 0, Train Loss: 0.0019, Train Accuracy: 100.00%
# Epoch 64, Batch 100, Train Loss: 0.0200, Train Accuracy: 99.22%
# Epoch 64, Batch 200, Train Loss: 0.0334, Train Accuracy: 99.22%
# Epoch 64, Batch 300, Train Loss: 0.0104, Train Accuracy: 99.22%
# Epoch 64, Batch 400, Train Loss: 0.0130, Train Accuracy: 99.22%
# Epoch 64, Val Loss: 0.0000, Val Accuracy: 99.54%
# Epoch 65, Batch 0, Train Loss: 0.0172, Train Accuracy: 99.22%
# Epoch 65, Batch 100, Train Loss: 0.0138, Train Accuracy: 99.22%
# Epoch 65, Batch 200, Train Loss: 0.0054, Train Accuracy: 100.00%
# Epoch 65, Batch 300, Train Loss: 0.0007, Train Accuracy: 100.00%
# Epoch 65, Batch 400, Train Loss: 0.0354, Train Accuracy: 99.22%
# Epoch 65, Val Loss: 0.0001, Val Accuracy: 99.46%
# Epoch 66, Batch 0, Train Loss: 0.0210, Train Accuracy: 99.22%
# Epoch 66, Batch 100, Train Loss: 0.0025, Train Accuracy: 100.00%
# Epoch 66, Batch 200, Train Loss: 0.0078, Train Accuracy: 100.00%
# Epoch 66, Batch 300, Train Loss: 0.0017, Train Accuracy: 100.00%
# Epoch 66, Batch 400, Train Loss: 0.0169, Train Accuracy: 99.22%
# Epoch 66, Val Loss: 0.0000, Val Accuracy: 99.49%
# Epoch 67, Batch 0, Train Loss: 0.0012, Train Accuracy: 100.00%
# Epoch 67, Batch 100, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 67, Batch 200, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 67, Batch 300, Train Loss: 0.0047, Train Accuracy: 100.00%
# Epoch 67, Batch 400, Train Loss: 0.0023, Train Accuracy: 100.00%
# Epoch 67, Val Loss: 0.0000, Val Accuracy: 99.56%
# Epoch 68, Batch 0, Train Loss: 0.0011, Train Accuracy: 100.00%
# Epoch 68, Batch 100, Train Loss: 0.0034, Train Accuracy: 100.00%
# Epoch 68, Batch 200, Train Loss: 0.0025, Train Accuracy: 100.00%
# Epoch 68, Batch 300, Train Loss: 0.0016, Train Accuracy: 100.00%
# Epoch 68, Batch 400, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 68, Val Loss: 0.0002, Val Accuracy: 99.49%
# Epoch 69, Batch 0, Train Loss: 0.0139, Train Accuracy: 99.22%
# Epoch 69, Batch 100, Train Loss: 0.0335, Train Accuracy: 99.22%
# Epoch 69, Batch 200, Train Loss: 0.0012, Train Accuracy: 100.00%
# Epoch 69, Batch 300, Train Loss: 0.0141, Train Accuracy: 99.22%
# Epoch 69, Batch 400, Train Loss: 0.0072, Train Accuracy: 100.00%
# Epoch 69, Val Loss: 0.0000, Val Accuracy: 99.48%
# Epoch 70, Batch 0, Train Loss: 0.0015, Train Accuracy: 100.00%
# Epoch 70, Batch 100, Train Loss: 0.0131, Train Accuracy: 99.22%
# Epoch 70, Batch 200, Train Loss: 0.0005, Train Accuracy: 100.00%
# Epoch 70, Batch 300, Train Loss: 0.0005, Train Accuracy: 100.00%
# Epoch 70, Batch 400, Train Loss: 0.0035, Train Accuracy: 100.00%
# Epoch 70, Val Loss: 0.0000, Val Accuracy: 99.52%
# Epoch 71, Batch 0, Train Loss: 0.0051, Train Accuracy: 100.00%
# Epoch 71, Batch 100, Train Loss: 0.0292, Train Accuracy: 98.44%
# Epoch 71, Batch 200, Train Loss: 0.0012, Train Accuracy: 100.00%
# Epoch 71, Batch 300, Train Loss: 0.0048, Train Accuracy: 100.00%
# Epoch 71, Batch 400, Train Loss: 0.0019, Train Accuracy: 100.00%
# Epoch 71, Val Loss: 0.0001, Val Accuracy: 99.49%
# Epoch 72, Batch 0, Train Loss: 0.0020, Train Accuracy: 100.00%
# Epoch 72, Batch 100, Train Loss: 0.0013, Train Accuracy: 100.00%
# Epoch 72, Batch 200, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 72, Batch 300, Train Loss: 0.0021, Train Accuracy: 100.00%
# Epoch 72, Batch 400, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 72, Val Loss: 0.0000, Val Accuracy: 99.55%
# Epoch 73, Batch 0, Train Loss: 0.0020, Train Accuracy: 100.00%
# Epoch 73, Batch 100, Train Loss: 0.0069, Train Accuracy: 100.00%
# Epoch 73, Batch 200, Train Loss: 0.0057, Train Accuracy: 100.00%
# Epoch 73, Batch 300, Train Loss: 0.0043, Train Accuracy: 100.00%
# Epoch 73, Batch 400, Train Loss: 0.0010, Train Accuracy: 100.00%
# Epoch 73, Val Loss: 0.0000, Val Accuracy: 99.52%
# Epoch 74, Batch 0, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 74, Batch 100, Train Loss: 0.0553, Train Accuracy: 97.66%
# Epoch 74, Batch 200, Train Loss: 0.0012, Train Accuracy: 100.00%
# Epoch 74, Batch 300, Train Loss: 0.0040, Train Accuracy: 100.00%
# Epoch 74, Batch 400, Train Loss: 0.0038, Train Accuracy: 100.00%
# Epoch 74, Val Loss: 0.0013, Val Accuracy: 99.36%
# Epoch 75, Batch 0, Train Loss: 0.0010, Train Accuracy: 100.00%
# Epoch 75, Batch 100, Train Loss: 0.0059, Train Accuracy: 100.00%
# Epoch 75, Batch 200, Train Loss: 0.0416, Train Accuracy: 98.44%
# Epoch 75, Batch 300, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 75, Batch 400, Train Loss: 0.0070, Train Accuracy: 100.00%
# Epoch 75, Val Loss: 0.0000, Val Accuracy: 99.54%
# Epoch 76, Batch 0, Train Loss: 0.0410, Train Accuracy: 99.22%
# Epoch 76, Batch 100, Train Loss: 0.0112, Train Accuracy: 99.22%
# Epoch 76, Batch 200, Train Loss: 0.0016, Train Accuracy: 100.00%
# Epoch 76, Batch 300, Train Loss: 0.0108, Train Accuracy: 100.00%
# Epoch 76, Batch 400, Train Loss: 0.0054, Train Accuracy: 100.00%
# Epoch 76, Val Loss: 0.0000, Val Accuracy: 99.44%
# Epoch 77, Batch 0, Train Loss: 0.0006, Train Accuracy: 100.00%
# Epoch 77, Batch 100, Train Loss: 0.0013, Train Accuracy: 100.00%
# Epoch 77, Batch 200, Train Loss: 0.0076, Train Accuracy: 100.00%
# Epoch 77, Batch 300, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 77, Batch 400, Train Loss: 0.0018, Train Accuracy: 100.00%
# Epoch 77, Val Loss: 0.0000, Val Accuracy: 99.54%
# Epoch 78, Batch 0, Train Loss: 0.0155, Train Accuracy: 99.22%
# Epoch 78, Batch 100, Train Loss: 0.0010, Train Accuracy: 100.00%
# Epoch 78, Batch 200, Train Loss: 0.0145, Train Accuracy: 99.22%
# Epoch 78, Batch 300, Train Loss: 0.0077, Train Accuracy: 99.22%
# Epoch 78, Batch 400, Train Loss: 0.0101, Train Accuracy: 99.22%
# Epoch 78, Val Loss: 0.0000, Val Accuracy: 99.55%
# Epoch 79, Batch 0, Train Loss: 0.0046, Train Accuracy: 100.00%
# Epoch 79, Batch 100, Train Loss: 0.0011, Train Accuracy: 100.00%
# Epoch 79, Batch 200, Train Loss: 0.0031, Train Accuracy: 100.00%
# Epoch 79, Batch 300, Train Loss: 0.0104, Train Accuracy: 99.22%
# Epoch 79, Batch 400, Train Loss: 0.0007, Train Accuracy: 100.00%
# Epoch 79, Val Loss: 0.0000, Val Accuracy: 99.50%
# Epoch 80, Batch 0, Train Loss: 0.0086, Train Accuracy: 100.00%
# Epoch 80, Batch 100, Train Loss: 0.0010, Train Accuracy: 100.00%
# Epoch 80, Batch 200, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 80, Batch 300, Train Loss: 0.0065, Train Accuracy: 100.00%
# Epoch 80, Batch 400, Train Loss: 0.0104, Train Accuracy: 100.00%
# Epoch 80, Val Loss: 0.0003, Val Accuracy: 99.50%
# Epoch 81, Batch 0, Train Loss: 0.0006, Train Accuracy: 100.00%
# Epoch 81, Batch 100, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 81, Batch 200, Train Loss: 0.0023, Train Accuracy: 100.00%
# Epoch 81, Batch 300, Train Loss: 0.0044, Train Accuracy: 100.00%
# Epoch 81, Batch 400, Train Loss: 0.0069, Train Accuracy: 99.22%
# Epoch 81, Val Loss: 0.0000, Val Accuracy: 99.52%
# Epoch 82, Batch 0, Train Loss: 0.0057, Train Accuracy: 100.00%
# Epoch 82, Batch 100, Train Loss: 0.0017, Train Accuracy: 100.00%
# Epoch 82, Batch 200, Train Loss: 0.0025, Train Accuracy: 100.00%
# Epoch 82, Batch 300, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 82, Batch 400, Train Loss: 0.0046, Train Accuracy: 100.00%
# Epoch 82, Val Loss: 0.0001, Val Accuracy: 99.56%
# Epoch 83, Batch 0, Train Loss: 0.0024, Train Accuracy: 100.00%
# Epoch 83, Batch 100, Train Loss: 0.0080, Train Accuracy: 100.00%
# Epoch 83, Batch 200, Train Loss: 0.0010, Train Accuracy: 100.00%
# Epoch 83, Batch 300, Train Loss: 0.0014, Train Accuracy: 100.00%
# Epoch 83, Batch 400, Train Loss: 0.0087, Train Accuracy: 100.00%
# Epoch 83, Val Loss: 0.0001, Val Accuracy: 99.55%
# Epoch 84, Batch 0, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 84, Batch 100, Train Loss: 0.0006, Train Accuracy: 100.00%
# Epoch 84, Batch 200, Train Loss: 0.0536, Train Accuracy: 99.22%
# Epoch 84, Batch 300, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 84, Batch 400, Train Loss: 0.0134, Train Accuracy: 99.22%
# Epoch 84, Val Loss: 0.0000, Val Accuracy: 99.51%
# Epoch 85, Batch 0, Train Loss: 0.0103, Train Accuracy: 99.22%
# Epoch 85, Batch 100, Train Loss: 0.0010, Train Accuracy: 100.00%
# Epoch 85, Batch 200, Train Loss: 0.0034, Train Accuracy: 100.00%
# Epoch 85, Batch 300, Train Loss: 0.0005, Train Accuracy: 100.00%
# Epoch 85, Batch 400, Train Loss: 0.0020, Train Accuracy: 100.00%
# Epoch 85, Val Loss: 0.0000, Val Accuracy: 99.52%
# Epoch 86, Batch 0, Train Loss: 0.0106, Train Accuracy: 99.22%
# Epoch 86, Batch 100, Train Loss: 0.0060, Train Accuracy: 100.00%
# Epoch 86, Batch 200, Train Loss: 0.0019, Train Accuracy: 100.00%
# Epoch 86, Batch 300, Train Loss: 0.0007, Train Accuracy: 100.00%
# Epoch 86, Batch 400, Train Loss: 0.0031, Train Accuracy: 100.00%
# Epoch 86, Val Loss: 0.0000, Val Accuracy: 99.49%
# Epoch 87, Batch 0, Train Loss: 0.0032, Train Accuracy: 100.00%
# Epoch 87, Batch 100, Train Loss: 0.0042, Train Accuracy: 100.00%
# Epoch 87, Batch 200, Train Loss: 0.0025, Train Accuracy: 100.00%
# Epoch 87, Batch 300, Train Loss: 0.0015, Train Accuracy: 100.00%
# Epoch 87, Batch 400, Train Loss: 0.0017, Train Accuracy: 100.00%
# Epoch 87, Val Loss: 0.0000, Val Accuracy: 99.55%
# Epoch 88, Batch 0, Train Loss: 0.0007, Train Accuracy: 100.00%
# Epoch 88, Batch 100, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 88, Batch 200, Train Loss: 0.0020, Train Accuracy: 100.00%
# Epoch 88, Batch 300, Train Loss: 0.0007, Train Accuracy: 100.00%
# Epoch 88, Batch 400, Train Loss: 0.0020, Train Accuracy: 100.00%
# Epoch 88, Val Loss: 0.0000, Val Accuracy: 99.61%
# Epoch 89, Batch 0, Train Loss: 0.0062, Train Accuracy: 100.00%
# Epoch 89, Batch 100, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 89, Batch 200, Train Loss: 0.0079, Train Accuracy: 99.22%
# Epoch 89, Batch 300, Train Loss: 0.0005, Train Accuracy: 100.00%
# Epoch 89, Batch 400, Train Loss: 0.0021, Train Accuracy: 100.00%
# Epoch 89, Val Loss: 0.0000, Val Accuracy: 99.59%
# Epoch 90, Batch 0, Train Loss: 0.0014, Train Accuracy: 100.00%
# Epoch 90, Batch 100, Train Loss: 0.0522, Train Accuracy: 99.22%
# Epoch 90, Batch 200, Train Loss: 0.0013, Train Accuracy: 100.00%
# Epoch 90, Batch 300, Train Loss: 0.0086, Train Accuracy: 99.22%
# Epoch 90, Batch 400, Train Loss: 0.0014, Train Accuracy: 100.00%
# Epoch 90, Val Loss: 0.0000, Val Accuracy: 99.54%
# Epoch 91, Batch 0, Train Loss: 0.0146, Train Accuracy: 99.22%
# Epoch 91, Batch 100, Train Loss: 0.0003, Train Accuracy: 100.00%
# Epoch 91, Batch 200, Train Loss: 0.0010, Train Accuracy: 100.00%
# Epoch 91, Batch 300, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 91, Batch 400, Train Loss: 0.0017, Train Accuracy: 100.00%
# Epoch 91, Val Loss: 0.0002, Val Accuracy: 99.59%
# Epoch 92, Batch 0, Train Loss: 0.0089, Train Accuracy: 99.22%
# Epoch 92, Batch 100, Train Loss: 0.0049, Train Accuracy: 100.00%
# Epoch 92, Batch 200, Train Loss: 0.0006, Train Accuracy: 100.00%
# Epoch 92, Batch 300, Train Loss: 0.0060, Train Accuracy: 100.00%
# Epoch 92, Batch 400, Train Loss: 0.0015, Train Accuracy: 100.00%
# Epoch 92, Val Loss: 0.0000, Val Accuracy: 99.56%
# Epoch 93, Batch 0, Train Loss: 0.0041, Train Accuracy: 100.00%
# Epoch 93, Batch 100, Train Loss: 0.0040, Train Accuracy: 100.00%
# Epoch 93, Batch 200, Train Loss: 0.0029, Train Accuracy: 100.00%
# Epoch 93, Batch 300, Train Loss: 0.0016, Train Accuracy: 100.00%
# Epoch 93, Batch 400, Train Loss: 0.0034, Train Accuracy: 100.00%
# Epoch 93, Val Loss: 0.0000, Val Accuracy: 99.61%
# Epoch 94, Batch 0, Train Loss: 0.0018, Train Accuracy: 100.00%
# Epoch 94, Batch 100, Train Loss: 0.0782, Train Accuracy: 98.44%
# Epoch 94, Batch 200, Train Loss: 0.0087, Train Accuracy: 100.00%
# Epoch 94, Batch 300, Train Loss: 0.0015, Train Accuracy: 100.00%
# Epoch 94, Batch 400, Train Loss: 0.0010, Train Accuracy: 100.00%
# Epoch 94, Val Loss: 0.0002, Val Accuracy: 99.54%
# Epoch 95, Batch 0, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 95, Batch 100, Train Loss: 0.0019, Train Accuracy: 100.00%
# Epoch 95, Batch 200, Train Loss: 0.0006, Train Accuracy: 100.00%
# Epoch 95, Batch 300, Train Loss: 0.0019, Train Accuracy: 100.00%
# Epoch 95, Batch 400, Train Loss: 0.0028, Train Accuracy: 100.00%
# Epoch 95, Val Loss: 0.0000, Val Accuracy: 99.55%
# Epoch 96, Batch 0, Train Loss: 0.0070, Train Accuracy: 100.00%
# Epoch 96, Batch 100, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 96, Batch 200, Train Loss: 0.0031, Train Accuracy: 100.00%
# Epoch 96, Batch 300, Train Loss: 0.0043, Train Accuracy: 100.00%
# Epoch 96, Batch 400, Train Loss: 0.0014, Train Accuracy: 100.00%
# Epoch 96, Val Loss: 0.0000, Val Accuracy: 99.56%
# Epoch 97, Batch 0, Train Loss: 0.0014, Train Accuracy: 100.00%
# Epoch 97, Batch 100, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 97, Batch 200, Train Loss: 0.0044, Train Accuracy: 100.00%
# Epoch 97, Batch 300, Train Loss: 0.0007, Train Accuracy: 100.00%
# Epoch 97, Batch 400, Train Loss: 0.0093, Train Accuracy: 99.22%
# Epoch 97, Val Loss: 0.0000, Val Accuracy: 99.54%
# Epoch 98, Batch 0, Train Loss: 0.0032, Train Accuracy: 100.00%
# Epoch 98, Batch 100, Train Loss: 0.0010, Train Accuracy: 100.00%
# Epoch 98, Batch 200, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 98, Batch 300, Train Loss: 0.0012, Train Accuracy: 100.00%
# Epoch 98, Batch 400, Train Loss: 0.0028, Train Accuracy: 100.00%
# Epoch 98, Val Loss: 0.0000, Val Accuracy: 99.54%
# Epoch 99, Batch 0, Train Loss: 0.0013, Train Accuracy: 100.00%
# Epoch 99, Batch 100, Train Loss: 0.0345, Train Accuracy: 99.22%
# Epoch 99, Batch 200, Train Loss: 0.0049, Train Accuracy: 100.00%
# Epoch 99, Batch 300, Train Loss: 0.0022, Train Accuracy: 100.00%
# Epoch 99, Batch 400, Train Loss: 0.0068, Train Accuracy: 100.00%
# Epoch 99, Val Loss: 0.0001, Val Accuracy: 99.54%
# Epoch 100, Batch 0, Train Loss: 0.0027, Train Accuracy: 100.00%
# Epoch 100, Batch 100, Train Loss: 0.0086, Train Accuracy: 99.22%
# Epoch 100, Batch 200, Train Loss: 0.0017, Train Accuracy: 100.00%
# Epoch 100, Batch 300, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 100, Batch 400, Train Loss: 0.0016, Train Accuracy: 100.00%
# Epoch 100, Val Loss: 0.0000, Val Accuracy: 99.58%

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/100332814.py in <cell line: 0>()
#      22
#      23 # 使用方法
# ---> 24 errors = analyze_errors(model, train_loader['val'], device)
#      25 print(f"找到 {len(errors)} 个错误分类样本")
#      26
#
# TypeError: 'DataLoader' object is not subscriptable

# %%
# 以下代碼執行後可以判斷你的作答是否正確，請勿修改

task_grader.q3_1_check(criterion, optimizer)
task_grader.q3_2_check(train_losses, val_losses, train_accs, val_accs)

# %% [markdown]
# ### 可視化
#
# 以下是一段將數據集進行可視化的代碼，如果前面的代碼編寫正確，會顯示一行圖片，並顯示模型識別出該圖片是哪一個數字

# %%
def visualize_predictions(loader, model, title):
    images, true_labels = next(iter(loader))
    images = images.to(device)
    
    model.eval()
    with torch.no_grad():
        outputs = model(images)
        pred_probs = torch.softmax(outputs, dim=1)
        pred_labels = outputs.argmax(dim=1)
    
    images = images[:20].cpu()
    true_labels = true_labels[:20]
    pred_labels = pred_labels[:20].cpu()
    pred_probs = pred_probs[:20].cpu()
    
    plt.figure(figsize=(15, 3))
    plt.suptitle(title, fontsize=16)
    
    for i in range(20):
        plt.subplot(1, 20, i+1)
        img = images[i].squeeze()
        
        plt.imshow(img.numpy(), cmap='gray' if img.dim() == 2 else None)
        pred_prob = pred_probs[i][pred_labels[i]].item()
        plt.title(f"Prediction: {pred_labels[i].item()}, Answer: {true_labels[i].item()}", 
                 color='green' if pred_labels[i].item() == true_labels[i].item() else 'red')
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

visualize_predictions(val_loader, model, "Predictions")

# %% [markdown]
# ### 提交
#
# 以下代碼會生成一個 `submission.csv`，選手只需要在右側菜單中選擇 `Submit to competition > Submit` 就可以完成提交

# %%
import torch
import pandas as pd

test_images = torch.load('/kaggle/input/moai-2025-training/test_images.pt', weights_only=True)
# TODO: 按照前面的方法歸一化
test_images = test_images/255.0

model.eval()
with torch.no_grad():
    test_images = test_images.to(device)
    outputs = model(test_images)
    predictions = outputs.argmax(dim=1)

df_test = pd.DataFrame({"label": predictions.cpu().numpy()})
df_test.to_csv("submission2.csv", index_label="id")
